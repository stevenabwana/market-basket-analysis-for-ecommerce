# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
data = pd.read_csv("trxns.csv")
head= data.head()
columns = data.columns
print(head)
print("-"*100)
print(columns)
print("-"*100)
# Out:
#       Ref StockCode                                Descr  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  Price  Customer ID         Country
# 0  12/1/2010 8:26   2.55      17850.0  United Kingdom
# 1  12/1/2010 8:26   3.39      17850.0  United Kingdom
# 2  12/1/2010 8:26   2.75      17850.0  United Kingdom
# 3  12/1/2010 8:26   3.39      17850.0  United Kingdom
# 4  12/1/2010 8:26   3.39      17850.0  United Kingdom
# ----------------------------------------------------------------------------------------------------
# Index(['Ref', 'StockCode', 'Descr', 'Quantity', 'InvoiceDate', 'Price',
#        'Customer ID', 'Country'],
#       dtype='object')
# ----------------------------------------------------------------------------------------------------

# %%
Ref = data.Ref.unique()
print("AVAILABLE TRANSACTIONS")
print(Ref)
print("-"*100)
# Out:
# AVAILABLE TRANSACTIONS
# ['536365' '536366' '536368' ... '581585' '581586' '581587']
# ----------------------------------------------------------------------------------------------------

# %%
basket = (data.groupby(["Ref","Descr"])["Quantity"]).sum().unstack().reset_index().fillna(0).set_index('Ref')
basket
# Out:
# Descr     4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# Ref
# 536365                              0.0                             0.0
# 536366                              0.0                             0.0
# 536367                              0.0                             0.0
# 536368                              0.0                             0.0
# 536369                              0.0                             0.0
# ...                                 ...                             ...
# C581484                             0.0                             0.0
# C581490                             0.0                             0.0
# C581499                             0.0                             0.0
# C581568                             0.0                             0.0
# C581569                             0.0                             0.0
#
# Descr     DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# Ref
# 536365                  0.0                           0.0
# 536366                  0.0                           0.0
# 536367                  0.0                           0.0
# 536368                  0.0                           0.0
# 536369                  0.0                           0.0
# ...                     ...                           ...
# C581484                 0.0                           0.0
# C581490                 0.0                           0.0
# C581499                 0.0                           0.0
# C581568                 0.0                           0.0
# C581569                 0.0                           0.0
#
# Descr     I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# Ref
# 536365                            0.0                       0.0
# 536366                            0.0                       0.0
# 536367                            0.0                       0.0
# 536368                            0.0                       0.0
# 536369                            0.0                       0.0
# ...                               ...                       ...
# C581484                           0.0                       0.0
# C581490                           0.0                       0.0
# C581499                           0.0                       0.0
# C581568                           0.0                       0.0
# C581569                           0.0                       0.0
#
# Descr     OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# Ref
# 536365                           0.0                       0.0
# 536366                           0.0                       0.0
# 536367                           0.0                       0.0
# 536368                           0.0                       0.0
# 536369                           0.0                       0.0
# ...                              ...                       ...
# C581484                          0.0                       0.0
# C581490                          0.0                       0.0
# C581499                          0.0                       0.0
# C581568                          0.0                       0.0
# C581569                          0.0                       0.0
#
# Descr     SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# Ref                                                                 ...
# 536365                                0.0                      0.0  ...
# 536366                                0.0                      0.0  ...
# 536367                                0.0                      0.0  ...
# 536368                                0.0                      0.0  ...
# 536369                                0.0                      0.0  ...
# ...                                   ...                      ...  ...
# C581484                               0.0                      0.0  ...
# C581490                               0.0                      0.0  ...
# C581499                               0.0                      0.0  ...
# C581568                               0.0                      0.0  ...
# C581569                               0.0                      0.0  ...
#
# Descr    wrongly coded 20713  wrongly coded 23343  wrongly coded-23343  \
# Ref
# 536365                   0.0                  0.0                  0.0
# 536366                   0.0                  0.0                  0.0
# 536367                   0.0                  0.0                  0.0
# 536368                   0.0                  0.0                  0.0
# 536369                   0.0                  0.0                  0.0
# ...                      ...                  ...                  ...
# C581484                  0.0                  0.0                  0.0
# C581490                  0.0                  0.0                  0.0
# C581499                  0.0                  0.0                  0.0
# C581568                  0.0                  0.0                  0.0
# C581569                  0.0                  0.0                  0.0
#
# Descr    wrongly marked  wrongly marked 23343  wrongly marked carton 22804  \
# Ref
# 536365              0.0                   0.0                          0.0
# 536366              0.0                   0.0                          0.0
# 536367              0.0                   0.0                          0.0
# 536368              0.0                   0.0                          0.0
# 536369              0.0                   0.0                          0.0
# ...                 ...                   ...                          ...
# C581484             0.0                   0.0                          0.0
# C581490             0.0                   0.0                          0.0
# C581499             0.0                   0.0                          0.0
# C581568             0.0                   0.0                          0.0
# C581569             0.0                   0.0                          0.0
#
# Descr    wrongly marked. 23343 in box  wrongly sold (22719) barcode  \
# Ref
# 536365                            0.0                           0.0
# 536366                            0.0                           0.0
# 536367                            0.0                           0.0
# 536368                            0.0                           0.0
# 536369                            0.0                           0.0
# ...                               ...                           ...
# C581484                           0.0                           0.0
# C581490                           0.0                           0.0
# C581499                           0.0                           0.0
# C581568                           0.0                           0.0
# C581569                           0.0                           0.0
#
# Descr    wrongly sold as sets  wrongly sold sets
# Ref
# 536365                    0.0                0.0
# 536366                    0.0                0.0
# 536367                    0.0                0.0
# 536368                    0.0                0.0
# 536369                    0.0                0.0
# ...                       ...                ...
# C581484                   0.0                0.0
# C581490                   0.0                0.0
# C581499                   0.0                0.0
# C581568                   0.0                0.0
# C581569                   0.0                0.0
#
# [24446 rows x 4223 columns]

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

# %%
basket_encoded = basket.applymap(hot_encode)
basket = basket_encoded

print("ENCODED")
print(basket)
# Out:
# ENCODED
# Descr     4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# Ref
# 536365                                0                               0
# 536366                                0                               0
# 536367                                0                               0
# 536368                                0                               0
# 536369                                0                               0
# ...                                 ...                             ...
# C581484                               0                               0
# C581490                               0                               0
# C581499                               0                               0
# C581568                               0                               0
# C581569                               0                               0
#
# Descr     DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# Ref
# 536365                    0                             0
# 536366                    0                             0
# 536367                    0                             0
# 536368                    0                             0
# 536369                    0                             0
# ...                     ...                           ...
# C581484                   0                             0
# C581490                   0                             0
# C581499                   0                             0
# C581568                   0                             0
# C581569                   0                             0
#
# Descr     I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# Ref
# 536365                              0                         0
# 536366                              0                         0
# 536367                              0                         0
# 536368                              0                         0
# 536369                              0                         0
# ...                               ...                       ...
# C581484                             0                         0
# C581490                             0                         0
# C581499                             0                         0
# C581568                             0                         0
# C581569                             0                         0
#
# Descr     OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# Ref
# 536365                             0                         0
# 536366                             0                         0
# 536367                             0                         0
# 536368                             0                         0
# 536369                             0                         0
# ...                              ...                       ...
# C581484                            0                         0
# C581490                            0                         0
# C581499                            0                         0
# C581568                            0                         0
# C581569                            0                         0
#
# Descr     SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# Ref                                                                 ...
# 536365                                  0                        0  ...
# 536366                                  0                        0  ...
# 536367                                  0                        0  ...
# 536368                                  0                        0  ...
# 536369                                  0                        0  ...
# ...                                   ...                      ...  ...
# C581484                                 0                        0  ...
# C581490                                 0                        0  ...
# C581499                                 0                        0  ...
# C581568                                 0                        0  ...
# C581569                                 0                        0  ...
#
# Descr    wrongly coded 20713  wrongly coded 23343  wrongly coded-23343  \
# Ref
# 536365                     0                    0                    0
# 536366                     0                    0                    0
# 536367                     0                    0                    0
# 536368                     0                    0                    0
# 536369                     0                    0                    0
# ...                      ...                  ...                  ...
# C581484                    0                    0                    0
# C581490                    0                    0                    0
# C581499                    0                    0                    0
# C581568                    0                    0                    0
# C581569                    0                    0                    0
#
# Descr    wrongly marked  wrongly marked 23343  wrongly marked carton 22804  \
# Ref
# 536365                0                     0                            0
# 536366                0                     0                            0
# 536367                0                     0                            0
# 536368                0                     0                            0
# 536369                0                     0                            0
# ...                 ...                   ...                          ...
# C581484               0                     0                            0
# C581490               0                     0                            0
# C581499               0                     0                            0
# C581568               0                     0                            0
# C581569               0                     0                            0
#
# Descr    wrongly marked. 23343 in box  wrongly sold (22719) barcode  \
# Ref
# 536365                              0                             0
# 536366                              0                             0
# 536367                              0                             0
# 536368                              0                             0
# 536369                              0                             0
# ...                               ...                           ...
# C581484                             0                             0
# C581490                             0                             0
# C581499                             0                             0
# C581568                             0                             0
# C581569                             0                             0
#
# Descr    wrongly sold as sets  wrongly sold sets
# Ref
# 536365                      0                  0
# 536366                      0                  0
# 536367                      0                  0
# 536368                      0                  0
# 536369                      0                  0
# ...                       ...                ...
# C581484                     0                  0
# C581490                     0                  0
# C581499                     0                  0
# C581568                     0                  0
# C581569                     0                  0
#
# [24446 rows x 4223 columns]

# %%
frq_items = apriori(basket, min_support = 0.02, use_colnames = True)
print("Frequent Items")
print(frq_items)
# Out:
# Frequent Items
#       support                                           itemsets
# 0    0.039066                           (6 RIBBONS RUSTIC CHARM)
# 1    0.025280                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 2    0.033871                      (60 TEATIME FAIRY CAKE CASES)
# 3    0.025157                   (72 SWEETHEART FAIRY CAKE CASES)
# 4    0.040088                       (ALARM CLOCK BAKELIKE GREEN)
# ..        ...                                                ...
# 226  0.020249  (RED HANGING HEART T-LIGHT HOLDER, WHITE HANGI...
# 227  0.020699  (RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOT...
# 228  0.021476  (REGENCY CAKESTAND 3 TIER, ROSES REGENCY TEACU...
# 229  0.022049  (WOODEN PICTURE FRAME WHITE FINISH, WOODEN FRA...
# 230  0.022171  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
#
# [231 rows x 2 columns]

# %%
rules = association_rules(frq_items, metric="lift", min_threshold=1)
rules.head()
# Out:
#                      antecedents                    consequents  \
# 0    (ALARM CLOCK BAKELIKE RED )   (ALARM CLOCK BAKELIKE GREEN)
# 1   (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED )
# 2  (RED RETROSPOT CHARLOTTE BAG)  (CHARLOTTE BAG PINK POLKADOT)
# 3  (CHARLOTTE BAG PINK POLKADOT)  (RED RETROSPOT CHARLOTTE BAG)
# 4  (RED RETROSPOT CHARLOTTE BAG)    (CHARLOTTE BAG SUKI DESIGN)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.042993            0.040088  0.026180    0.608944  15.190043
# 1            0.040088            0.042993  0.026180    0.653061  15.190043
# 2            0.042297            0.030394  0.021353    0.504836  16.609974
# 3            0.030394            0.042297  0.021353    0.702557  16.609974
# 4            0.042297            0.036080  0.020740    0.490329  13.590225
#
#    leverage  conviction
# 0  0.024457    2.454665
# 1  0.024457    2.758433
# 2  0.020068    1.958151
# 3  0.020068    3.219788
# 4  0.019214    1.891260
